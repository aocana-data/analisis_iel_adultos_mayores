# %%
from monstry.Builder import Builder
from monstry.DataCleaner import DataCleaner

# %%
json_file = './analisis_calidad_adultos_mayores/config/config.json'
builder = Builder( config_path = json_file)
# Out:
# Se ha creado usando un archivo de configuracion

# %%
adultos_mayores = DataCleaner(builder, 'adultos_mayores' )
# Out:
# Se ha cargado efectivamente el dataframe
#
#         Informacion:
#             _ get_completitud():
#                 Se obtienen la completutid de la tabla
#             - get_exactitud():
#                 Se obtiene la exactitud de la tabla siempre y cuando los valores por default sean completados
#                 en el archivo de configuraciones o tengan un valor por defecto
#             ----------------------------------------------------------------------------------------------------
#             - get_resumen():
#                 Se obtiene un dataframe con el análisis de completitud y exactitud del dataset seleccionado
# /home/anderson/Documents/analisis/monstry_goayvd/monstry/modules/dataframes_uri_def.py:26: DtypeWarning: Columns (14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)

# %%
adultos_mayores.get_completitud()
adultos_mayores.completitud
# Out:
# Analisis de completitud sin tener en cuenta ningún tipo de caracter especial, simplemente por valores nulos
# Analisis de completitud finalizado
#  * Para observar los resultados solo de "Completitud" visualizar con .completitud
#                COLUMNA     NOMBRE TABLA  REGISTROS TOTALES  \
# 0       insertion_date  adultos_mayores              51523
# 1        ultimo_examen  adultos_mayores              51523
# 2         nrodocumento  adultos_mayores              51523
# 3     fecha_formulario  adultos_mayores              51523
# 4                 cuil  adultos_mayores              51523
# 5            localidad  adultos_mayores              51523
# 6               genero  adultos_mayores              51523
# 7             apellido  adultos_mayores              51523
# 8               altura  adultos_mayores              51523
# 9   fecha_alta_usuario  adultos_mayores              51523
# 10      tipo_documento  adultos_mayores              51523
# ...

# %%
adultos_mayores.get_exactitud()
adultos_mayores.exactitud
# Out:
# Analisis de completitud sin tener en cuenta ningún tipo de caracter especial, simplemente por valores nulos
# Analisis de completitud finalizado
#  * Para observar los resultados solo de "Completitud" visualizar con .completitud
# Analisis de exactitud finalizado
# * Para observar los resultados solo de "Exactitud" visualizar con .exactitud
#                COLUMNA  EXACTO  INEXACTO  PORCENTAJE DE EXACTITUD
# 0               altura   48924      1278                    97.45
# 1               genero   51523         0                   100.00
# 2         nrodocumento   51483        38                    99.93
# 3               estado   51523         0                   100.00
# 4            municipio      21         0                   100.00
# 5            provincia   51523         0                   100.00
# 6               nombre   51504        18                    99.97
# 7         plan_estudio   51523         0                   100.00
# ...

# %%
adultos_mayores.estado_columna()
# Out:
#         Conteo de cantidad de registros por caracteres determinados como nulls por el usuario
#         como valores de default.
#                     CANTIDAD VALORES UNICOS  CANTIDAD VALORES DUPLICADOS  \
# estado                                    8                        51515
# fecha_nacimiento                      16738                        34785
# municipio                                21                            0
# calle                                 20490                        30988
# provincia                                25                        51498
# nombre                                29548                        21975
# cp                                     2026                        43210
# plan_estudio                              2                        51521
# tipo_documento                            8                        51515
# fecha_alta_usuario                      992                        32076
# ...

# %%
adultos_mayores.get_resumen()
# Out:
# Analisis de completitud sin tener en cuenta ningún tipo de caracter especial, simplemente por valores nulos
# Analisis de completitud finalizado
#  * Para observar los resultados solo de "Completitud" visualizar con .completitud
# Analisis de exactitud finalizado
# * Para observar los resultados solo de "Exactitud" visualizar con .exactitud
#                COLUMNA     NOMBRE TABLA  REGISTROS TOTALES  \
# 0       insertion_date  adultos_mayores              51523
# 1        ultimo_examen  adultos_mayores              51523
# 2         nrodocumento  adultos_mayores              51523
# 3     fecha_formulario  adultos_mayores              51523
# 4                 cuil  adultos_mayores              51523
# 5            localidad  adultos_mayores              51523
# 6               genero  adultos_mayores              51523
# 7             apellido  adultos_mayores              51523
# 8               altura  adultos_mayores              51523
# ...

# %%
adultos_mayores.to_csv(file_name = "adultos_mayores")
# Out:
# /home/anderson/Documents/analisis/monstry_goayvd/monstry

# %%
adultos_mayores.__inexactos__()
# Out:
# -----------------------------------------------altura-----------------------------------------------
# 14               lote 134
# 32             51 TORRE 2
# 67     Manzana 12 Lote 30
# 135           Av escalada
# 144            Av caseros
# Name: altura, dtype: object
# --------------------------------------------nrodocumento--------------------------------------------
# 190       117385
# 195       136832
# 199       178312
# 202    192622777
# 215       308222
# Name: nrodocumento, dtype: object
# -----------------------------------------------nombre-----------------------------------------------
# 1458       Esther R.
# 3424    FLORENCIA M.
# 3565    GRISELDA .E.
# 6551       BENEDA B.
# 7517      JOSE LUIS|
# Name: nombre, dtype: object
# ----------------------------------------------apellido----------------------------------------------
# 21492               Marcial.
# 26552    ROTONDO DELLEPIANIº
# Name: apellido, dtype: object
# ...

# %%
adultos_mayores.__exactos__()
# Out:
# -----------------------------------------------altura-----------------------------------------------
# 0    1232
# 1    5382
# 2     658
# 3    1744
# 4    5658
# Name: altura, dtype: object
# --------------------------------------------nrodocumento--------------------------------------------
# 0    11111120
# 1    11805551
# 2    14059444
# 3    14128759
# 4    16252608
# Name: nrodocumento, dtype: object
# -----------------------------------------------nombre-----------------------------------------------
# 1        Liliana Alicia
# 2       Griselda Susana
# 3             Ana Maria
# 4      Graciela Beatriz
# 5    MARISA EDIT ISABEL
# Name: nombre, dtype: object
# ----------------------------------------------apellido----------------------------------------------
# 1             MARTINEZ
# 2    Benítez DE Ninnis
# 3               Fulini
# 4               Alanis
# 5             BERTUZZI
# Name: apellido, dtype: object
# ...
