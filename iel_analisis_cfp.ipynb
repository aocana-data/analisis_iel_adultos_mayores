# %%
from monstry.Builder import Builder
from monstry.DataCleaner import DataCleaner

# %%
json_file = './analisis_calidad_iel_cfp/config/config.json'
builder = Builder( config_path = json_file)
# Out:
# Se ha creado usando un archivo de configuracion

# %%
iel_cfp = DataCleaner(builder, 'iel_cfp' )
# Out:
# Se ha cargado efectivamente el dataframe
#
#         Informacion:
#             _ get_completitud():
#                 Se obtienen la completutid de la tabla
#             - get_exactitud():
#                 Se obtiene la exactitud de la tabla siempre y cuando los valores por default sean completados
#                 en el archivo de configuraciones o tengan un valor por defecto
#             ----------------------------------------------------------------------------------------------------
#             - get_resumen():
#                 Se obtiene un dataframe con el análisis de completitud y exactitud del dataset seleccionado

# %%
iel_cfp.get_completitud()
iel_cfp.completitud
# Out:
# Analisis de completitud sin tener en cuenta ningún tipo de caracter especial, simplemente por valores nulos
# Analisis de completitud finalizado
#  * Para observar los resultados solo de "Completitud" visualizar con .completitud
#                      COLUMNA NOMBRE TABLA  REGISTROS TOTALES  \
# 0   insert_into_dl_timestamp      iel_cfp              24245
# 1             nivel_estudios      iel_cfp              24245
# 2                  profesion      iel_cfp              24245
# 3         localidadprovincia      iel_cfp              24245
# 4                  provincia      iel_cfp              24245
# 5       direccion_estudiante      iel_cfp              24245
# 6           fecha_nacimiento      iel_cfp              24245
# 7                       sexo      iel_cfp              24245
# 8               nacionalidad      iel_cfp              24245
# 9                   telefono      iel_cfp              24245
# 10                     email      iel_cfp              24245
# ...

# %%
iel_cfp.get_exactitud()
iel_cfp.exactitud
# Out:
# Analisis de completitud sin tener en cuenta ningún tipo de caracter especial, simplemente por valores nulos
# Analisis de completitud finalizado
#  * Para observar los resultados solo de "Completitud" visualizar con .completitud
# /home/anderson/Documents/analisis/monstry_goayvd/venv/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# ⚠️WARNING:
# 	LA COLUMNA "sorteo" ES COMPLETAMENTE NULA, POR LO TANTO VALOR DE EXACTITUD ES SETEADO A 0
# Analisis de exactitud finalizado
# * Para observar los resultados solo de "Exactitud" visualizar con .exactitud
#                      COLUMNA  EXACTO  INEXACTO  PORCENTAJE DE EXACTITUD
# 0               nrodocumento   24134       106                    99.56
# 1                       sexo   24245         0                   100.00
# 2                   telefono   20776        59                    99.72
# ...

# %%
iel_cfp.analisis_por_categoria(*iel_cfp.columnas)
# Out:
# ----------------------------------------------------------------------------------------------------
# Filas totales:
#  24245
#
# Registros con variable "nivel":
#  24245
#
# Cantidad de nulos:
#  0
#
# Valores distintos:
#  ['Formación Profesional']
#
# Cantidad de filas por valor:
#  nivel
# Formación Profesional    24245
# Name: nivel, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Filas totales:
#  24245
#
# Registros con variable "sede":
#  24245
#
# Cantidad de nulos:
#  0
#
# Valores distintos:
#  ['C.F.P. Nº 10 Monserrat' 'C.F.P. Nº 18' 'C.F.P. Nº 34' 'C.F.P. Nº 24'
#  'C.F.P. Nº 15 - Villa 21-24' 'C.F.P. Nº 25'
#  'C.F.P. Nº 12 San Nicolas, Tucuman 615' 'C.F.P. Nº 10 Flores'
#  'C.F.P. Nº 13' 'C.F.P. Nº 07' 'C.F.P. Nº 20'
#  'C.F.P. Nº 12 Balvanera, Tucuman 2214' 'C.F.P. Nº 33' 'C.F.P. Nº 31'
#  'C.F.P. Nº 19 - Parroquia Santa Elisa' 'C.F.P. Nº 06' 'C.F.P. Nº 30'
# ...

# %%
iel_cfp.get_resumen()
# Out:
# Analisis de completitud sin tener en cuenta ningún tipo de caracter especial, simplemente por valores nulos
# Analisis de completitud finalizado
#  * Para observar los resultados solo de "Completitud" visualizar con .completitud
# /home/anderson/Documents/analisis/monstry_goayvd/venv/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# ⚠️WARNING:
# 	LA COLUMNA "sorteo" ES COMPLETAMENTE NULA, POR LO TANTO VALOR DE EXACTITUD ES SETEADO A 0
# Analisis de exactitud finalizado
# * Para observar los resultados solo de "Exactitud" visualizar con .exactitud
#                      COLUMNA NOMBRE TABLA  REGISTROS TOTALES  \
# 0   insert_into_dl_timestamp      iel_cfp              24245
# 1             nivel_estudios      iel_cfp              24245
# 2                  profesion      iel_cfp              24245
# 3         localidadprovincia      iel_cfp              24245
# ...

# %%
iel_cfp.to_csv(file_name = "iel_cfp")
# Out:
# /home/anderson/Documents/analisis/monstry_goayvd/monstry

# %%
iel_cfp.__inexactos__()
# Out:
# --------------------------------------------nrodocumento--------------------------------------------
# 642      118152876
# 803     43769643-3
# 1350     361042020
# 1433     161667126
# 1867     PP5244108
# Name: nrodocumento, dtype: object
# ----------------------------------------------telefono----------------------------------------------
# 1206          0
# 1394    4088942
# 4529          1
# 7465    1111111
# 8587    2330320
# Name: telefono, dtype: object
# -----------------------------------------------email------------------------------------------------
# 2806     GUILLERMO.SEMANIUK@CA1492.COM
# 20364          CHEGUILOPEZ@39GMAIL.COM
# 22839             susanasego32@yahoo.c
# 23086         DARIELGONZAAS@GMAILÑ.COM
# 23410         nahuel.reyna@3mar.com.ar
# Name: email, dtype: object
# -----------------------------------------------curso------------------------------------------------
# 15              DECORADOR ARTESANAL DE TORTAS (MODULO I)
# ...

# %%
iel_cfp.__exactos__()
# Out:
# --------------------------------------------nrodocumento--------------------------------------------
# 0    39426374
# 1    96091324
# 2    28815613
# 3    93966818
# 4    42624462
# Name: nrodocumento, dtype: object
# ----------------------------------------------telefono----------------------------------------------
# 0    1130368383
# 1    1127287153
# 2    1134268251
# 3    1568863349
# 4    1165740810
# Name: telefono, dtype: object
# -----------------------------------------------email------------------------------------------------
# 0       m.angelicairibarren@gmail.com
# 1            giselaramirezu@gmail.com
# 2             ramirezmaia88@gmail.com
# 3                 ttechy258@gmail.com
# 4    arapacioli@entedelaciudad.gov.ar
# Name: email, dtype: object
# -----------------------------------------------curso------------------------------------------------
# 0                                         Portugués  I
# 1        Técnicas de liquidación de sueldos y jornales
# ...
