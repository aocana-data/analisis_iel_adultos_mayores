# %%
from monstry.Builder import Builder
from monstry.DataCleaner import DataCleaner

# %%
json_file = './analisis_calidad_iel_ifts/config/config.json'
builder = Builder( config_path = json_file)
# Out:
# Se ha creado usando un archivo de configuracion

# %%
iel_ifts = DataCleaner(builder, 'iel_ifts' )
# Out:
# Se ha cargado efectivamente el dataframe
#
#         Informacion:
#             _ get_completitud():
#                 Se obtienen la completutid de la tabla
#             - get_exactitud():
#                 Se obtiene la exactitud de la tabla siempre y cuando los valores por default sean completados
#                 en el archivo de configuraciones o tengan un valor por defecto
#             ----------------------------------------------------------------------------------------------------
#             - get_resumen():
#                 Se obtiene un dataframe con el análisis de completitud y exactitud del dataset seleccionado

# %%
iel_ifts.get_completitud()
iel_ifts.completitud
# Out:
# Analisis de completitud sin tener en cuenta ningún tipo de caracter especial, simplemente por valores nulos
# Analisis de completitud finalizado
#  * Para observar los resultados solo de "Completitud" visualizar con .completitud
#                      COLUMNA NOMBRE TABLA  REGISTROS TOTALES  \
# 0   insert_into_dl_timestamp     iel_ifts               6256
# 1                      turno     iel_ifts               6256
# 2                supervisión     iel_ifts               6256
# 3            establecimiento     iel_ifts               6256
# 4                   prov_alu     iel_ifts               6256
# 5                     barrio     iel_ifts               6256
# 6                    partido     iel_ifts               6256
# 7                  direccion     iel_ifts               6256
# 8    certificadodiscapacidad     iel_ifts               6256
# 9                 disc_otros     iel_ifts               6256
# 10                discmental     iel_ifts               6256
# ...

# %%
iel_ifts.get_exactitud()
iel_ifts.exactitud
# Out:
# Analisis de completitud sin tener en cuenta ningún tipo de caracter especial, simplemente por valores nulos
# Analisis de completitud finalizado
#  * Para observar los resultados solo de "Completitud" visualizar con .completitud
# Analisis de exactitud finalizado
# * Para observar los resultados solo de "Exactitud" visualizar con .exactitud
#                      COLUMNA  EXACTO  INEXACTO  PORCENTAJE DE EXACTITUD
# 0                      email    4858         2                    99.96
# 1              mail_creacion    6256         0                   100.00
# 2                        año    6256         0                   100.00
# 3                         id    6256         0                   100.00
# 4               nrodocumento    6244         8                    99.87
# 5                    carrera    6256         0                   100.00
# 6                     estado    6256         0                   100.00
# ...

# %%
iel_ifts.get_resumen()
# Out:
# Analisis de completitud sin tener en cuenta ningún tipo de caracter especial, simplemente por valores nulos
# Analisis de completitud finalizado
#  * Para observar los resultados solo de "Completitud" visualizar con .completitud
# Analisis de exactitud finalizado
# * Para observar los resultados solo de "Exactitud" visualizar con .exactitud
#                      COLUMNA NOMBRE TABLA  REGISTROS TOTALES  \
# 0   insert_into_dl_timestamp     iel_ifts               6256
# 1                      turno     iel_ifts               6256
# 2                supervisión     iel_ifts               6256
# 3            establecimiento     iel_ifts               6256
# 4                   prov_alu     iel_ifts               6256
# 5                     barrio     iel_ifts               6256
# 6                    partido     iel_ifts               6256
# 7                  direccion     iel_ifts               6256
# 8    certificadodiscapacidad     iel_ifts               6256
# ...

# %%
iel_ifts.analisis_por_categoria(*iel_ifts.columnas)
# Out:
# ----------------------------------------------------------------------------------------------------
# Filas totales:
#  6256
#
# Registros con variable "año":
#  6256
#
# Cantidad de nulos:
#  0
#
# Valores distintos:
#  [2021]
#
# Cantidad de filas por valor:
#  año
# 2021    6256
# Name: año, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Filas totales:
#  6256
#
# Registros con variable "id":
#  6256
#
# Cantidad de nulos:
#  0
#
# Valores distintos:
#  [34471085 34385875 33468805 ... 35023094 34536668 35293209]
#
# Cantidad de filas por valor:
#  id
# 33330702    1
# 35012170    1
# 35011472    1
# 35010882    1
# 35010657    1
# 35010500    1
# 35010477    1
# 35009579    1
# 35009311    1
# 35009116    1
# 35012508    1
# 35009110    1
# 35008711    1
# 35006830    1
# 35006085    1
# 35005610    1
# 35005544    1
# 35005399    1
# 35005195    1
# 35000080    1
# Name: id, dtype: int64
# ...

# %%
iel_ifts.to_csv(file_name = "iel_ifts")
# Out:
# /home/anderson/Documents/analisis/monstry_goayvd/monstry

# %%
iel_ifts.__inexactos__()
iel_ifts.__exactos__()
# Out:
# -----------------------------------------------email------------------------------------------------
# 959     nilagonsalez@21gmail.com
# 2873    vargasalbert@29gmail.com
# Name: email, dtype: object
# ---------------------------------------------direccion----------------------------------------------
# 73                                              9
# 117    BONORINO, ESTEBAN, CNEL. AV. y RIESTRA AV.
# 251                                             4
# 270                  DIAZ, AVELINO y CARABOBO AV.
# 317          Boulogne sur mer y antofagasta s/n.
# Name: direccion, dtype: object
# --------------------------------------------nrodocumento--------------------------------------------
# 453      N07937413
# 465      Pp4091981
# 2881     PP5244108
# 3357    39.230.912
# 4143      AT114010
# Name: nrodocumento, dtype: object
# ---------------------------------------------disc_otros---------------------------------------------
# 103                  C.A de Cervix en tratamiento.
# ...
